# %%
import scrapy

# %%
# !scrapy runspider spiderMinimo.py
# Out:
# /usr/local/lib/python3.8/site-packages/scrapy/commands/__init__.py:131: ScrapyDeprecationWarning: ('The -t command line option is deprecated in favor of specifying the output format within the output URI. See the documentation of the -o and -O options for more information.',)
#   feeds = feed_process_params_from_cli(
# 2020-12-30 11:59:00 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-30 11:59:00 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.6 (default, Nov 20 2020, 23:57:10) - [Clang 12.0.0 (clang-1200.0.32.27)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1i  8 Dec 2020), cryptography 3.3.1, Platform macOS-11.1-x86_64-i386-64bit
# 2020-12-30 11:59:00 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-30 11:59:00 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# ...

# %%
# !scrapy runspider Web_Scrapping_Python.py -t json -o artigos.json

# %%
# !scrapy runspider Web_Scrapping_Python.py -t csv -o artigos.csv
# Out:
# /usr/local/lib/python3.8/site-packages/scrapy/commands/__init__.py:131: ScrapyDeprecationWarning: ('The -t command line option is deprecated in favor of specifying the output format within the output URI. See the documentation of the -o and -O options for more information.',)
#   feeds = feed_process_params_from_cli(
# 2020-12-30 12:02:03 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-30 12:02:03 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.6 (default, Nov 20 2020, 23:57:10) - [Clang 12.0.0 (clang-1200.0.32.27)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1i  8 Dec 2020), cryptography 3.3.1, Platform macOS-11.1-x86_64-i386-64bit
# 2020-12-30 12:02:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-30 12:02:03 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# ...

# %%
# !scrapy startproject crawlerIGTI
# Out:
# New Scrapy project 'crawlerIGTI', using template directory '/usr/local/lib/python3.8/site-packages/scrapy/templates/project', created in:
#     /Users/Gustavo-NB/bootcamp_ciencia_de_dados/Modulo_2/Desafio/crawlerIGTI
#
# You can start your first spider with:
#     cd crawlerIGTI
#     scrapy genspider example example.com

# %%
import os

os.chdir('/Users/Gustavo-NB/bootcamp_ciencia_de_dados/Modulo_2/Desafio/crawlerIGTI')

# %%
# !scrapy genspider scrapingIGTIBlog www.igti.com.br/blog
# !scrapy genspider crawlingIGTIBlog www.igti.com.br/blog
# Out:
# Spider 'scrapingIGTIBlog' already exists in module:
#   crawlerIGTI.spiders.scrapingIGTIBlog
# Created spider 'crawlingIGTIBlog' using template 'basic' in module:
#   crawlerIGTI.spiders.crawlingIGTIBlog

# %%
# !scrapy runspider /Users/Gustavo-NB/bootcamp_ciencia_de_dados/Modulo_2/Desafio/crawlerIGTI/crawlerIGTI/spiders/crawlingIGTIBlog.py
# Out:
# 2021-01-02 16:36:56 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: crawlerIGTI)
# 2021-01-02 16:36:56 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.6 (default, Nov 20 2020, 23:57:10) - [Clang 12.0.0 (clang-1200.0.32.27)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1i  8 Dec 2020), cryptography 3.3.1, Platform macOS-11.1-x86_64-i386-64bit
# 2021-01-02 16:36:56 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-01-02 16:36:56 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawlerIGTI',
#  'NEWSPIDER_MODULE': 'crawlerIGTI.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'SPIDER_MODULES': ['crawlerIGTI.spiders']}
# 2021-01-02 16:36:56 [scrapy.extensions.telnet] INFO: Telnet Password: 854730898e25c458
# 2021-01-02 16:36:56 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# !scrapy runspider /Users/Gustavo-NB/bootcamp_ciencia_de_dados/Modulo_2/Desafio/crawlerIGTI/crawlerIGTI/spiders/scrapingIGTIBlog.py
# Out:
# 2021-01-02 16:26:48 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: crawlerIGTI)
# 2021-01-02 16:26:48 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.6 (default, Nov 20 2020, 23:57:10) - [Clang 12.0.0 (clang-1200.0.32.27)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1i  8 Dec 2020), cryptography 3.3.1, Platform macOS-11.1-x86_64-i386-64bit
# 2021-01-02 16:26:48 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-01-02 16:26:48 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'crawlerIGTI',
#  'NEWSPIDER_MODULE': 'crawlerIGTI.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'SPIDER_MODULES': ['crawlerIGTI.spiders']}
# 2021-01-02 16:26:48 [scrapy.extensions.telnet] INFO: Telnet Password: e5517bf7ad72563e
# 2021-01-02 16:26:48 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...
